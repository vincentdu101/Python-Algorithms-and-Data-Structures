# %% [markdown]
# Given n non-negative integers a1, a2, ..., an , where each represents a point at coordinate (i, ai). n vertical lines are drawn such that the two endpoints of the line i is at (i, ai) and (i, 0). Find two lines, which, together with the x-axis forms a container, such that the container contains the most water.
#
# Notice that you may not slant the container.
#
#
#
# Example 1:
#
# ![image.png](attachment:image.png)
#
# Input: height = [1,8,6,2,5,4,8,3,7]
#
# Output: 49
#
# Explanation: The above vertical lines are represented by array [1,8,6,2,5,4,8,3,7]. In this case, the max area of water (blue section) the container can contain is 49.

# %%
class Solution:
    
    def __init__(self) -> None:
        # empty constructor so we pass
        pass
    
    def maxArea(self, height) -> int:
        end = len(height) - 1
        left = 0
        output = 0
        right = end
        shorter = 0
        
        # start each end of the array, using two pointers and 
        # slowly move towards each other to determine the max 
        # area each time
        while left < end and right > 0:
            # get the highest height possible 
            highest = self.getHighest(height, left, right)
            
            # height multiply by width in difference between the two
            # end points to get the area
            temp = highest * (right - left)
            
            # if the new area is bigger than what was saved, we 
            # override the saved one 
            if output < temp:
                output = temp
            
            # see which is the smaller height and increment/decrement
            # from that 
            if height[left] > height[right]:
                right -= 1
            else:
                left += 1
        return output
    
    def getHighest(self, height, left, end) -> int:
        # determine which element has the lower height
        # because that's the max height we can hold the water
        # without overfilling
        if height[left] > height[end]:
            return height[end]
        else:
            return height[left]

# %%
solution = Solution()
print("Max Area: ", solution.maxArea([1,8,6,2,5,4,8,3,7]))
# Out:
# Max Area:  49
